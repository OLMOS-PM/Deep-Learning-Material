# %% [markdown]
# # Lab: Image Autoencoder with CNNs
#
#
# ------------------------------------------------------
# *Pablo M. Olmos pamartin@ing.uc3m.es*
#
# ------------------------------------------------------
#
#
# In this notebook, we'll build a convolutional autoencoder to compress the CIFAR10 dataset. The encoder portion will be made of convolutional and pooling layers and the decoder will be made of **transpose convolutional layers** that learn to "upsample" a compressed representation.
#
# Note: a big part of the following material is a personal wrap-up of [Facebook's Deep Learning Course in Udacity](https://www.udacity.com/course/deep-learning-pytorch--ud188). So all credit goes for them!!

# %%
from IPython.display import Image
from IPython.core.display import HTML 

Image(url= "https://iq.opengenus.org/content/images/2019/03/autoencoder_1.png", width=800, height=200)
# Out:
# <img src="https://iq.opengenus.org/content/images/2019/03/autoencoder_1.png" width="800" height="200"/>

# %% [markdown]
# ## Part I. Load CIFAR10. Visualize images
#
# Lets copy code that we've used in previous labs to load, normalize and visualize CIFAR10 images.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision import utils


import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Define the transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load the dataset
trainset = datasets.CIFAR10(root='~/torch_datasets', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=2)

testset = datasets.CIFAR10(root='~/torch_datasets', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /Users/alancho/torch_datasets/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:06<00:00, 25633218.78it/s]
# Extracting /Users/alancho/torch_datasets/cifar-10-python.tar.gz to /Users/alancho/torch_datasets
# Files already downloaded and verified

# %% [markdown]
# Lets visualize one image ...

# %%
traindata = iter(trainloader)

images, labels = next(traindata)

print(images[1].shape)

def rescale(img):
    img = img / 2 + 0.5     # unnormalize to pot
    npimg = img.numpy()
    return np.transpose(npimg, (1, 2, 0))

plt.imshow(rescale(images[0,:,:,:]))
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# > **Exercise**: Check the range of every pixel in a normalized image. This will help you to select the appropiate activation function in the autoencoder.

# %%
# YOUR CODE HERE

print(torch.max(images))

print(torch.min(images))
# Out:
# tensor(1.)
# tensor(-1.)

# %% [markdown]
# > **Exercise:** Create a validation set with 5000 images

# %%
# YOUR CODE HERE

import copy
validloader    = copy.deepcopy(trainloader)  # Creates a copy of the object 
total_data     = trainloader.dataset.data.shape[0]
valid_delimit   = total_data - 5000

#We take the first 55000 images for training
trainloader.dataset.data = trainloader.dataset.data[:valid_delimit,:,:,:]
trainloader.dataset.targets = trainloader.dataset.targets[:valid_delimit]

#And the rest 5000 for validation
validloader.dataset.data = validloader.dataset.data[valid_delimit:,:,:,:]
validloader.dataset.targets = validloader.dataset.targets[valid_delimit:]

# %% [markdown]
# ---
# ## Part II. Create the convolutional  autoencoder
#
# ### Encoder
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer
# will be followed by a max-pooling layer to reduce the dimensions of the layers.
#
# ### Decoder
#
# The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide, reconstructed image. For example, the representation could be a 7x7x4 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the compressed representation. A schematic of the network is shown below.
#
# **Note:** For CIFAR 10 we start with 32x32x3 images, and the encoder output will be of dimension 8x8xC, where C is the number of feature maps at the output. We will study the effect of C in reconstructing images.

# %%
Image(url= "https://iq.opengenus.org/content/images/2019/03/autoencoder_3.png", width=400)
# Out:
# <img src="https://iq.opengenus.org/content/images/2019/03/autoencoder_3.png" width="400"/>

# %% [markdown]
# In the MNIST example, the encoder layer has size 7x7x4 = 196. The original images have size 28x28 = 784, so the encoded vector is 25% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, in fact, you're encouraged to add additional layers to make this representation even smaller! Remember our goal here is to find a small representation of the input data.
#
# ### Transpose Convolutions, Decoder
#
# This decoder uses **transposed convolutional** layers to increase the width and height of the input layers. They work almost exactly the same as convolutional layers, but in reverse. A stride in the input layer results in a larger stride in the transposed convolution layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a transposed convolution layer. PyTorch provides us with an easy way to create the layers, [`nn.ConvTranspose2d`](https://pytorch.org/docs/stable/nn.html#convtranspose2d).
#
# It is important to note that transpose convolution layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer.  For simplicity, **we will put a convolution layer after the transpose convolutional layers to remove the artifacts.**
#
# > **Exercise:** Complete the following code, in which we build the autoencoder using a series of convolutional layers, pooling layers, and transpose convolutional layers. When building the decoder, recall that transpose convolutional layers can upsample an input by a factor of 2 using a stride and kernel_size of 2.

# %%
import torch.nn as nn
from torch import optim
import time

# define the NN architecture
class ConvAutoencoder(nn.Module):
    def __init__(self,C=4):
        super().__init__()

        #C is the number of feature maps of the encoder's output

        self.n_channel_latent = C

        print("The dimension of the latent representation is {0:f}".format((32/4)**2*self.n_channel_latent))
        
        ## Encoder layers ##
        # conv layer (depth from 3 --> 16), 3x3 kernels
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, 
                               kernel_size=3, stride=1, padding=1)
        
        # conv layer (depth from 16 --> C), 3x3 kernels
        # YOUR CODE HERE
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=self.n_channel_latent, 
                               kernel_size=3, stride=1, padding=1)
        
        # Max pool layer
        self.pool = nn.MaxPool2d(2, 2)
        
        ## decoder layers ##
        ## a kernel of 2 and a stride of 2 will increase the spatial dims by 2

        # trans conv layer (depth C --> 16)
        self.t_conv1 = nn.ConvTranspose2d(self.n_channel_latent, 16, kernel_size=2, stride=2)

        # trans conv layer (depth 16 --> 16)
        self.t_conv2 = nn.ConvTranspose2d(16, 16, kernel_size=2, stride=2)

        # conv layer (depth 16 --> 3) no spatial reduction!!
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=3, 
                               kernel_size=1, stride=1, padding=0)        

        ## BN Layers

        # One BN layer after the first two convolutional layers

        self.BN_1 = nn.BatchNorm2d(num_features=16)

        self.BN_2 = nn.BatchNorm2d(num_features=self.n_channel_latent)

        # One BN layer after the two transpose convolutional layers

        self.BN_3 = nn.BatchNorm2d(num_features=16)

        self.BN_4 = nn.BatchNorm2d(num_features=16)

        # We use RELU activation for all layers
        self.relu    = nn.ReLU()
        
        # And the appropiate activation at the decoder's output
        self.decoder_activation = nn.Tanh()
        

    def forward(self, x):

        x = self.conv1(x)
        x = self.BN_1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.BN_2(x)
        x = self.relu(x)
        x = self.pool(x)

        latent = x
        
        x = self.t_conv1(x)
        x = self.relu(x)
        x = self.BN_3(x)        
        x = self.t_conv2(x)
        x = self.relu(x)
        x = self.BN_4(x)         
        x = self.conv3(x)                
        x = self.decoder_activation(x)
        
        return x,latent

# %%
# initialize the NN for C=16 layers
model = ConvAutoencoder(C=16)
print(model)
# Out:
# The dimension of the latent representation is 1024.000000
# ConvAutoencoder(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(16, 16, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(16, 16, kernel_size=(2, 2), stride=(2, 2))
#   (conv3): Conv2d(16, 3, kernel_size=(1, 1), stride=(1, 1))
#   (BN_1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (decoder_activation): Tanh()
# )

# %% [markdown]
# ---
# ## Part III. Training
#
# > **Exercise:** Complete the class below to include a training method which monitors the reconstrution loss in both the training and validation datasets. In [this blog](https://medium.com/udacity-pytorch-challengers/a-brief-overview-of-loss-functions-in-pytorch-c0ddb78068f7) you can find a good summary of Pytorch Loss Functions. For the problem at hand, decide which one is more convenient.

# %%
class ConvAutoencoder_extended(ConvAutoencoder):
    
    def __init__(self, epochs=10, lr=0.01,C=4):
        
      super().__init__(C)
      self.lr = lr    
      self.optim = optim.Adam(self.parameters(), self.lr)   
      self.epochs = epochs

      self.criterion = nn.MSELoss() # YOUR CODE HERE
      
      self.loss_during_training = []
      self.valid_loss_during_training = []

      self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
      self.to(self.device)
        
    def trainloop(self,trainloader,validloader):
        
        # Optimization Loop
        
        for e in range(int(self.epochs)):
            
            running_loss = 0.
            start_time = time.time()
            for images, labels in trainloader:
        
                labels = images # To train an Autoencoder the label is the input

                # Move input and label tensors to the default device 
                images, labels = images.to(self.device), labels.to(self.device)

                self.optim.zero_grad()
            
                out = self.forward(images)[0]

                loss =  self.criterion(out, labels)
                
                running_loss += loss.item()

                loss.backward()
                
                self.optim.step()
                   
            self.loss_during_training.append(running_loss/len(trainloader))
            self.valid_loss_during_training.append(self.eval_performance(validloader))
                

            if(e % 1 == 0): # Every epoch

                print("Epoch %d. Training loss: %f, Validation loss: %f, Time per epoch: %f seconds" 
                      %(e,self.loss_during_training[-1],self.valid_loss_during_training[-1],
                       (time.time() - start_time)))

    def eval_performance(self,dataloader):

        # YOUR CODE HERE
                
        running_loss = 0.

        # Turn off gradients for validation, saves memory and computations
        with torch.no_grad():

            for images,labels in dataloader:

                labels = images # To train an Autoencoder the label is the input
                # Move input and label tensors to the default device 
                images, labels = images.to(self.device), labels.to(self.device)

                probs = self.forward(images)[0]
                
                loss =  self.criterion(probs, labels)
                running_loss += loss.item()
    
            return running_loss/len(dataloader)

# %% [markdown]
# > **Exercise:** Train the model for 5 epochs and plot both training and validation losses. Can you visualize overfitting?

# %%
# Your code here
autoencoder = ConvAutoencoder_extended(epochs = 5,C=16)
autoencoder.trainloop(trainloader,validloader)
# Out:
# The dimension of the latent representation is 1024.000000
# Epoch 0. Training loss: 0.027755, Validation loss: 0.021128, Time per epoch: 46.591067 seconds
# Epoch 1. Training loss: 0.016999, Validation loss: 0.017025, Time per epoch: 46.220397 seconds
# Epoch 2. Training loss: 0.015865, Validation loss: 0.016142, Time per epoch: 45.661468 seconds
# Epoch 3. Training loss: 0.015454, Validation loss: 0.015660, Time per epoch: 47.070458 seconds
# Epoch 4. Training loss: 0.015092, Validation loss: 0.015388, Time per epoch: 44.665126 seconds

# %%
# Your code here
plt.plot(autoencoder.loss_during_training)
plt.plot(autoencoder.valid_loss_during_training)
plt.legend(['Training loss', 'Validation loss'])

# %% [markdown]
# ### Checking out the results
#
# Below we plot some of the **test images** along with their reconstructions. These look a little rough around the edges, likely due to the artifacts that tend to happen with transpose layers.
#
# > **Exercise:** Complete the code (just one line!)

# %%
# obtain one batch of test images
dataiter = iter(testloader)
images, labels = next(dataiter)

batch_size=64


images_cuda, labels_cuda = images.to(autoencoder.device), labels.to(autoencoder.device)
# get sample outputs
# YOUR CODE HERE
output,latent = autoencoder(images_cuda)

# prep images for display


# output is resized into a batch of images
print(output.shape)
output = output.view(batch_size, 3, 32, 32)
# use detach when it's an output that requires_grad
output = output.cpu().detach()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for i in range(10):
    axes[0,i].imshow(rescale(images[i,:,:,:]))
    axes[1,i].imshow(rescale(output[i,:,:,:]))

    axes[0,i].get_xaxis().set_visible(False) # Remove legend
    axes[0,i].get_yaxis().set_visible(False)

    axes[1,i].get_xaxis().set_visible(False) # Remove legend
    axes[1,i].get_yaxis().set_visible(False)
# Out:
# torch.Size([64, 3, 32, 32])

# %% [markdown]
# ## Part IV. Visualizing the effect of the encoder size
#
# To analyze the effect of C, the number of feature maps at the encoder's output, represent the validation loss after training 5 epochs our autoencoder for different values of C between 2 and 32.

# %%
# Your code here
validation_losses = []
dimensions = []
for latent_dimension in range(2, 33, 2):
  print('Training with {} latent dimension...'.format(latent_dimension))
  autoencoder = ConvAutoencoder_extended(epochs = 5, C=latent_dimension)
  autoencoder.trainloop(trainloader,validloader)
  validation_losses.append(autoencoder.valid_loss_during_training[-1])
  dimensions.append(latent_dimension)
# Out:
# Training with 2 latent dimension...
# The dimension of the latent representation is 128.000000
# Epoch 0. Training loss: 0.060879, Validation loss: 0.054906, Time per epoch: 44.199760 seconds
# Epoch 1. Training loss: 0.054759, Validation loss: 0.054039, Time per epoch: 44.414065 seconds
# Epoch 2. Training loss: 0.054060, Validation loss: 0.053158, Time per epoch: 44.354341 seconds
# Epoch 3. Training loss: 0.053203, Validation loss: 0.052755, Time per epoch: 44.504155 seconds
# Epoch 4. Training loss: 0.052946, Validation loss: 0.052482, Time per epoch: 45.316035 seconds
# Training with 4 latent dimension...
# The dimension of the latent representation is 256.000000
# Epoch 0. Training loss: 0.038960, Validation loss: 0.032974, Time per epoch: 45.122967 seconds
# Epoch 1. Training loss: 0.029736, Validation loss: 0.028473, Time per epoch: 43.965319 seconds
# Epoch 2. Training loss: 0.028852, Validation loss: 0.029068, Time per epoch: 44.057586 seconds
# Epoch 3. Training loss: 0.028168, Validation loss: 0.027845, Time per epoch: 43.857968 seconds
# Epoch 4. Training loss: 0.027792, Validation loss: 0.027853, Time per epoch: 44.610918 seconds
# Training with 6 latent dimension...
# The dimension of the latent representation is 384.000000
# Epoch 0. Training loss: 0.036108, Validation loss: 0.027690, Time per epoch: 45.153080 seconds
# Epoch 1. Training loss: 0.026286, Validation loss: 0.024760, Time per epoch: 44.831946 seconds
# Epoch 2. Training loss: 0.024334, Validation loss: 0.025713, Time per epoch: 44.799214 seconds
# Epoch 3. Training loss: 0.023519, Validation loss: 0.024201, Time per epoch: 44.977608 seconds
# Epoch 4. Training loss: 0.023265, Validation loss: 0.023062, Time per epoch: 45.120494 seconds
# Training with 8 latent dimension...
# The dimension of the latent representation is 512.000000
# Epoch 0. Training loss: 0.032683, Validation loss: 0.022799, Time per epoch: 44.526203 seconds
# Epoch 1. Training loss: 0.021593, Validation loss: 0.020201, Time per epoch: 44.426759 seconds
# Epoch 2. Training loss: 0.020020, Validation loss: 0.019965, Time per epoch: 44.300539 seconds
# Epoch 3. Training loss: 0.019382, Validation loss: 0.019252, Time per epoch: 44.727406 seconds
# Epoch 4. Training loss: 0.018999, Validation loss: 0.019166, Time per epoch: 44.324346 seconds
# Training with 10 latent dimension...
# The dimension of the latent representation is 640.000000
# Epoch 0. Training loss: 0.032822, Validation loss: 0.023695, Time per epoch: 44.529493 seconds
# Epoch 1. Training loss: 0.021351, Validation loss: 0.020287, Time per epoch: 44.484602 seconds
# Epoch 2. Training loss: 0.018560, Validation loss: 0.018399, Time per epoch: 45.220382 seconds
# Epoch 3. Training loss: 0.017952, Validation loss: 0.018980, Time per epoch: 45.352968 seconds
# Epoch 4. Training loss: 0.017552, Validation loss: 0.018371, Time per epoch: 45.814544 seconds
# Training with 12 latent dimension...
# The dimension of the latent representation is 768.000000
# Epoch 0. Training loss: 0.030301, Validation loss: 0.020146, Time per epoch: 44.986973 seconds
# Epoch 1. Training loss: 0.018656, Validation loss: 0.017498, Time per epoch: 46.133865 seconds
# Epoch 2. Training loss: 0.017398, Validation loss: 0.016858, Time per epoch: 44.997463 seconds
# Epoch 3. Training loss: 0.016738, Validation loss: 0.018223, Time per epoch: 45.267867 seconds
# Epoch 4. Training loss: 0.016418, Validation loss: 0.016386, Time per epoch: 45.696479 seconds
# Training with 14 latent dimension...
# The dimension of the latent representation is 896.000000
# Epoch 0. Training loss: 0.029437, Validation loss: 0.020694, Time per epoch: 46.379978 seconds
# Epoch 1. Training loss: 0.018442, Validation loss: 0.017102, Time per epoch: 45.117552 seconds
# Epoch 2. Training loss: 0.016823, Validation loss: 0.016852, Time per epoch: 45.460349 seconds
# Epoch 3. Training loss: 0.016093, Validation loss: 0.016925, Time per epoch: 45.895293 seconds
# Epoch 4. Training loss: 0.015805, Validation loss: 0.015622, Time per epoch: 46.015437 seconds
# Training with 16 latent dimension...
# The dimension of the latent representation is 1024.000000
# Epoch 0. Training loss: 0.029310, Validation loss: 0.020402, Time per epoch: 45.927056 seconds
# Epoch 1. Training loss: 0.017947, Validation loss: 0.017012, Time per epoch: 47.878278 seconds
# Epoch 2. Training loss: 0.016618, Validation loss: 0.016176, Time per epoch: 47.290006 seconds
# Epoch 3. Training loss: 0.015885, Validation loss: 0.016194, Time per epoch: 46.302347 seconds
# Epoch 4. Training loss: 0.015321, Validation loss: 0.015771, Time per epoch: 46.684580 seconds
# Training with 18 latent dimension...
# The dimension of the latent representation is 1152.000000
# Epoch 0. Training loss: 0.028640, Validation loss: 0.019434, Time per epoch: 50.465420 seconds
# Epoch 1. Training loss: 0.017545, Validation loss: 0.017435, Time per epoch: 47.500610 seconds
# Epoch 2. Training loss: 0.015906, Validation loss: 0.015911, Time per epoch: 47.583311 seconds
# Epoch 3. Training loss: 0.015385, Validation loss: 0.015686, Time per epoch: 46.935325 seconds
# Epoch 4. Training loss: 0.014930, Validation loss: 0.015866, Time per epoch: 47.409113 seconds
# Training with 20 latent dimension...
# The dimension of the latent representation is 1280.000000
# Epoch 0. Training loss: 0.027882, Validation loss: 0.021658, Time per epoch: 47.467256 seconds
# Epoch 1. Training loss: 0.017064, Validation loss: 0.016966, Time per epoch: 47.164516 seconds
# Epoch 2. Training loss: 0.015499, Validation loss: 0.015183, Time per epoch: 47.379945 seconds
# Epoch 3. Training loss: 0.014808, Validation loss: 0.014467, Time per epoch: 47.654099 seconds
# Epoch 4. Training loss: 0.014315, Validation loss: 0.014029, Time per epoch: 47.836780 seconds
# Training with 22 latent dimension...
# The dimension of the latent representation is 1408.000000
# Epoch 0. Training loss: 0.026700, Validation loss: 0.016465, Time per epoch: 47.424495 seconds
# Epoch 1. Training loss: 0.016058, Validation loss: 0.015298, Time per epoch: 47.331367 seconds
# Epoch 2. Training loss: 0.014630, Validation loss: 0.014200, Time per epoch: 46.659387 seconds
# Epoch 3. Training loss: 0.014112, Validation loss: 0.015467, Time per epoch: 46.876563 seconds
# Epoch 4. Training loss: 0.013533, Validation loss: 0.014008, Time per epoch: 47.094442 seconds
# Training with 24 latent dimension...
# The dimension of the latent representation is 1536.000000
# Epoch 0. Training loss: 0.027229, Validation loss: 0.017182, Time per epoch: 46.906144 seconds
# Epoch 1. Training loss: 0.015909, Validation loss: 0.015840, Time per epoch: 47.493643 seconds
# Epoch 2. Training loss: 0.014426, Validation loss: 0.013907, Time per epoch: 47.056977 seconds
# Epoch 3. Training loss: 0.013535, Validation loss: 0.013864, Time per epoch: 47.054790 seconds
# Epoch 4. Training loss: 0.013303, Validation loss: 0.012402, Time per epoch: 47.064415 seconds
# Training with 26 latent dimension...
# The dimension of the latent representation is 1664.000000
# Epoch 0. Training loss: 0.026483, Validation loss: 0.018196, Time per epoch: 47.225046 seconds
# Epoch 1. Training loss: 0.016060, Validation loss: 0.015800, Time per epoch: 47.415198 seconds
# Epoch 2. Training loss: 0.014732, Validation loss: 0.014498, Time per epoch: 47.069665 seconds
# Epoch 3. Training loss: 0.013917, Validation loss: 0.013511, Time per epoch: 47.308736 seconds
# Epoch 4. Training loss: 0.013568, Validation loss: 0.013281, Time per epoch: 47.324938 seconds
# Training with 28 latent dimension...
# The dimension of the latent representation is 1792.000000
# Epoch 0. Training loss: 0.027744, Validation loss: 0.019184, Time per epoch: 47.436259 seconds
# Epoch 1. Training loss: 0.016770, Validation loss: 0.018541, Time per epoch: 47.343809 seconds
# Epoch 2. Training loss: 0.014749, Validation loss: 0.015035, Time per epoch: 47.468338 seconds
# Epoch 3. Training loss: 0.013937, Validation loss: 0.013601, Time per epoch: 48.191930 seconds
# Epoch 4. Training loss: 0.013628, Validation loss: 0.013999, Time per epoch: 48.158711 seconds
# Training with 30 latent dimension...
# The dimension of the latent representation is 1920.000000
# Epoch 0. Training loss: 0.027370, Validation loss: 0.018252, Time per epoch: 48.213375 seconds
# Epoch 1. Training loss: 0.015814, Validation loss: 0.014841, Time per epoch: 47.796446 seconds
# Epoch 2. Training loss: 0.014389, Validation loss: 0.014156, Time per epoch: 48.294575 seconds
# Epoch 3. Training loss: 0.013648, Validation loss: 0.013388, Time per epoch: 48.177119 seconds
# Epoch 4. Training loss: 0.013120, Validation loss: 0.012557, Time per epoch: 48.048087 seconds
# Training with 32 latent dimension...
# The dimension of the latent representation is 2048.000000
# Epoch 0. Training loss: 0.024844, Validation loss: 0.016235, Time per epoch: 49.084031 seconds
# Epoch 1. Training loss: 0.015080, Validation loss: 0.014313, Time per epoch: 48.541012 seconds
# Epoch 2. Training loss: 0.013784, Validation loss: 0.014360, Time per epoch: 48.301565 seconds
# Epoch 3. Training loss: 0.013013, Validation loss: 0.013225, Time per epoch: 47.908124 seconds
# Epoch 4. Training loss: 0.012717, Validation loss: 0.012701, Time per epoch: 47.775357 seconds

# %%
plt.plot(dimensions, validation_losses)
plt.xlabel('Latent dimensions')
plt.ylabel('Validation loss')
# Out:
# Text(0, 0.5, 'Validation loss')

# %% [markdown]
# ## Part V. Visualize the data the encoder's output in 2D using t-SNE
#
# [t-SNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) is a tool to visualize high-dimensional data. It converts similarities between data points to joint probabilities and tries to minimize the Kullback-Leibler divergence between the joint probabilities of the low-dimensional embedding and the high-dimensional data. t-SNE has a cost function that is not convex, i.e. with different initializations we can get different results.
#
# It is highly recommended to use another dimensionality reduction method (e.g. PCA for dense data or TruncatedSVD for sparse data) to reduce the number of dimensions to a reasonable amount (e.g. 100 or 200 variables) if the number of features is very high. At the end, this is what we used the autoencoder for!
#
# > **Exercise** For C=4, compute the latent representation of a mini-batch of CIFAR 10 images.

# %%
autoencoder = ConvAutoencoder_extended(epochs = 5,C=4)
autoencoder.trainloop(trainloader,validloader)
# Out:
# The dimension of the latent representation is 256.000000
# Epoch 0. Training loss: 0.040533, Validation loss: 0.032193, Time per epoch: 45.270763 seconds
# Epoch 1. Training loss: 0.030431, Validation loss: 0.030344, Time per epoch: 46.133938 seconds
# Epoch 2. Training loss: 0.029041, Validation loss: 0.028676, Time per epoch: 46.114113 seconds
# Epoch 3. Training loss: 0.028634, Validation loss: 0.028668, Time per epoch: 45.391758 seconds
# Epoch 4. Training loss: 0.028272, Validation loss: 0.028017, Time per epoch: 45.583921 seconds

# %%
_,latent = autoencoder.forward(images_cuda)

latent_cpu = latent.to('cpu').detach().numpy()

# %% [markdown]
# We implement TSNE using sklearn implementation

# %%
from sklearn.manifold import TSNE

# Reshape latent representation to a single vector
latent = latent_cpu.reshape(batch_size,-1)
images_np = np.squeeze(images)

latent_tsne = TSNE(n_components=2).fit_transform(latent)

# %%
# With this code we can visualize images in a 2D scatter plot

from matplotlib.offsetbox import OffsetImage, AnnotationBbox
 
def plot_latent_space_with_images(images,latent,xmin=-1,xmax=1,ymin=-1,ymax=1):
 
    # images --> Minibatch of images (numpy array!)
    # latent --> Matrix of 2D representations (numpy array!)
 
    f, ax = plt.subplots(1,1,figsize=(8, 8))
    # ax is a figure handle
    ax.clear()
    for i in range(len(images)):
        im = OffsetImage(rescale(images[i,:,:,:]))
        ab = AnnotationBbox(im, latent[i,:],frameon=False)
        ax.add_artist(ab)
    #We set the limits according to the maximum and minimum values found for the latent projections
    ax.set_xlim(xmin,xmax)
    ax.set_ylim(ymin,ymax)
    ax.set_title('Latent space Z with Images')

# %%
plot_latent_space_with_images(images, latent_tsne,-10,10,-10,10)

# %% [markdown]
# Do the neighbours in the 2D space make any sense?

# %%
# Out:
# Running cells with 'Python 3.12.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.12.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
